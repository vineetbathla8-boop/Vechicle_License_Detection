# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.118 🚀 Python-3.11.9 torch-2.13.0 CPU (Apple M5)
# Setup complete ✅ (10 CPUs, 24.0 GB RAM, 188.3/926.3 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ArMekV1ClpjLOsGdOSw1")
project = rf.workspace("vehicle-and-license").project("vehicle-license")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-License-2 in yolov11:: 100%|██████████| 19466/19466 [00:01<00:00, 13683.16it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

# %%
result = model.train( data = "/Users/vinni/Desktop/Veyra/Vehicle-License-2/data.yaml",
                     epochs=10,
                     imgsz = 640,device = "mps",) 


# device = "mps" is used as before my mac was using the cpu for the traing, but by giving device="mps", is uses the gpu
# Out:
# Ultralytics 8.4.118 🚀 Python-3.11.9 torch-2.13.0 MPS (Apple M5)
# ...

# %%
model_1 = YOLO("/Users/vinni/Desktop/VEHCILE_LICENSE/runs/detect/train-3/weights/best.pt")

# %%
result = model.predict(source ="/Users/vinni/Desktop/Vehcile_License/Vehicle-License-2/test/images/day-2_mp4-0664_jpg.rf.8bcf31bfaae84cff9318df193c53cd41.jpg")
# Out:
# image 1/1 /Users/vinni/Desktop/Vehcile_License/Vehicle-License-2/test/images/day-2_mp4-0664_jpg.rf.8bcf31bfaae84cff9318df193c53cd41.jpg: 640x640 2 persons, 2 cars, 2 trucks, 86.0ms
# Speed: 1.8ms preprocess, 86.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
imb = cv2.imread("https://file+.vscode-resource.vscode-cdn.net/Users/vinni/Desktop/Vehcile_License/Vehicle-License-2/test/images/day-2_mp4-0664_jpg.rf.8bcf31bfaae84cff9318df193c53cd41.jpg")
# Out:
# [ WARN:0@296.418] global loadsave.cpp:241 findDecoder imread_('https://file+.vscode-resource.vscode-cdn.net/Users/vinni/Desktop/Vehcile_License/Vehicle-License-2/test/images/day-2_mp4-0664_jpg.rf.8bcf31bfaae84cff9318df193c53cd41.jpg'): can't open/read file: check file path/integrity

# %%
cv2.imshow("Image",imb)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cv2.imshow("Image",imb)
#
# error: OpenCV(4.10.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/highgui/src/window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
print(type(imb))
print(imb is None)
print(imb.shape if imb is not None else "Image is None")
# Out:
# <class 'NoneType'>
# True
# Image is None
