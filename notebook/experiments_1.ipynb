# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.118 🚀 Python-3.11.9 torch-2.13.0 CPU (Apple M5)
# Setup complete ✅ (10 CPUs, 24.0 GB RAM, 188.2/926.3 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ArMekV1ClpjLOsGdOSw1")
project = rf.workspace("vehicle-and-license").project("vehicle-license")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-License-2 in yolov11:: 100%|██████████| 19466/19466 [00:01<00:00, 13969.94it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

# %%
result = model.train( data = "/Users/vinni/Desktop/Vehcile_License/notebook/Vehicle-License-2/data.yaml",
                     epochs=13,
                     imgsz = 640,device = "mps",) 


# device = "mps" is used as before my mac was using the cpu for the traing, but by giving device="mps", is uses the gpu
# Out:
# Ultralytics 8.4.118 🚀 Python-3.11.9 torch-2.13.0 MPS (Apple M5)
# ...

# %%
trained_model = YOLO("/Users/vinni/Desktop/Vehcile_License/notebook/runs/detect/train-3/weights/best.pt")

# %%
trained_model = trained_model.val(data ="/Users/vinni/Desktop/Vehcile_License/notebook/Vehicle-License-2/data.yaml" )
# Out:
# Ultralytics 8.4.118 🚀 Python-3.11.9 torch-2.13.0 CPU (Apple M5)
# YOLO11s summary (fused): 101 layers, 9,416,283 parameters, 0 gradients, 21.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 208.0±26.1 MB/s, size: 56.3 KB)
# val: Scanning /Users/vinni/Desktop/Vehcile_License/notebook/Vehicle-License-2/valid/labels.cache... 955 images, 15 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 955/955 250.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 60/60 5.6s/it 5:356.9ss
#                    all        955       4348      0.836      0.833      0.832      0.705
#                Bicycle          5          5      0.507      0.414      0.507      0.351
#                    Bus          8          9          1      0.437      0.476      0.471
#                    Car        747       1454      0.949      0.963      0.986      0.919
# ...

# %%
print(type(imb))
print(imb is None)
print(imb.shape if imb is not None else "Image is None")
# Out:
# <class 'NoneType'>
# True
# Image is None

# %%
find /Users/vinni/Desktop/Vehcile_License -name "data.yaml"
